# %% [markdown]
# # Machine Learning: A First ModelInstalling `scikit-learn` in-browser — this may take a moment the first time.

# %%
import micropipawait micropip.install("scikit-learn")from sklearn.linear_model import LinearRegressionimport numpy as npprint("scikit-learn ready")

# %% [markdown]
# ### Fit a simple line

# %%
X = np.array([[1], [2], [3], [4]])y = np.array([2, 4, 6, 8])model = LinearRegression().fit(X, y)print("Prediction for 5:", model.predict([[5]]))

# %% [markdown]
# ### Your turnChange the data points and see how the prediction changes.

# %%
# your code here
