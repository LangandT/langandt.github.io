# %% [markdown]
# # Python BasicsVariables, functions, and simple logic.

# %%
x = 5y = 3print(x + y, x - y, x * y, x / y)

# %% [markdown]
# ### Functions

# %%
def add(a, b):    return a + bprint(add(4, 7))

# %% [markdown]
# ### Your turnWrite a function that returns the square of a number, then call it.

# %%
# your code here
