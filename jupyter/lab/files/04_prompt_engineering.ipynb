# %% [markdown]
# # Prompt Engineering PracticeThis notebook is for practicing how to write clear, structured prompts. (Live API calls require a key and network access — for now, use this to draft and refine prompts before testing them in Claude or another assistant.)

# %%
prompt = """You are a helpful tutor. Explain photosynthesis to a 10-year-oldin under 100 words, using one everyday analogy."""print(prompt)

# %% [markdown]
# ### Your turnDraft a prompt for a task relevant to your course, and note what makes it clear and specific.

# %%
# your prompt draft here
