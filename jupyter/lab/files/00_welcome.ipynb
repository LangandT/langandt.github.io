# %% [markdown]
# # Welcome to the Lang & T Coding LabThis is a real Python environment running in your browser — powered by Jupyter and Pyodide. No installs needed.Run a cell by clicking it and pressing **Shift+Enter**.

# %%
print("Hello from Lang & T!")for i in range(3):    print("Round", i + 1)

# %% [markdown]
# ## Try it yourselfEdit the cell below and run it.

# %%
name = "your name here"print(f"Welcome, {name}!")
