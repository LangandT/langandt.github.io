# %% [markdown]
# # Data Analysis IntroThis notebook uses `pandas` — installed on demand via `micropip` since we're running in the browser.

# %%
import micropipawait micropip.install("pandas")import pandas as pdprint("pandas ready:", pd.__version__)

# %% [markdown]
# ### A simple dataset

# %%
data = {"name": ["Ada", "Bola", "Chinedu"], "score": [88, 92, 79]}df = pd.DataFrame(data)df

# %%
df["score"].mean()

# %% [markdown]
# ### Your turnAdd a new student to the dataset and recompute the average.

# %%
# your code here
